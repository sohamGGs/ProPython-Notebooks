# %%
class Camera:
    def take_photo(self): print("Snap! Photo taken.")

class Phone:
    def make_call(self): print("Calling...")

class SmartPhone(Camera, Phone):
    pass

if __name__ == "__main__":
    pixel = SmartPhone()
    pixel.take_photo()
    pixel.make_call()
# Out:
# Snap! Photo taken.
# Calling...
