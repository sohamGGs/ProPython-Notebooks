# %%
import re

log = "User Soham (ID: 5501) logged in with password 'secret123'"
# Censor anything inside single quotes
censored = re.sub(r"'.*?'", "'[REDACTED]'", log)

print(f"Safe Log: {censored}")
# Out:
# Safe Log: User Soham (ID: 5501) logged in with password '[REDACTED]'
