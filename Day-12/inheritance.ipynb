# %%
class Employee:
    def __init__(self, name: str, salary: float):
        self.name = name
        self.salary = salary

    def get_details(self) -> str:
        return f"Employee: {self.name} | Salary: ₹{self.salary}"

# Manager inherits from Employee
class Manager(Employee):
    def __init__(self, name: str, salary: float, department: str):
        # super() calls the Parent constructor
        super().__init__(name, salary)
        self.department = department

    # Method Overriding: Changing behavior of parent method
    def get_details(self) -> str:
        return f"Manager: {self.name} | Dept: {self.department} | Salary: ₹{self.salary}"

if __name__ == "__main__":
    emp = Employee("Rahul", 50000)
    mgr = Manager("Soham", 95000, "IT")
    print(emp.get_details())
    print(mgr.get_details())
# Out:
# Employee: Rahul | Salary: ₹50000
# Manager: Soham | Dept: IT | Salary: ₹95000
